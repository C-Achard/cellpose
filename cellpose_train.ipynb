# %%
from pathlib import Path
train_path = (Path().home() / "Desktop/cellpose/somatomotor_stacks").absolute()
val_path = (Path().home() / "Desktop/cellpose/visual_stacks").absolute()
print(train_path)
print(val_path)
# Out:
# /home/cyril/Desktop/cellpose/somatomotor_stacks
# /home/cyril/Desktop/cellpose/visual_stacks

# %%
# !python -m cellpose --train --n_epochs 100 --pretrained_model None --dir {str(train_path)} --test_dir {str(val_path)} --diam_mean=3.3 --verbose --use_gpu --do_3D --chan 0 --chan2 0
# Out:
# 2023-07-11 14:23:15,274 [INFO] WRITING LOG OUTPUT TO /home/cyril/.cellpose/run.log
# 2023-07-11 14:23:15,274 [INFO]
# cellpose version: 	2.2.2
# platform:       	linux
# python version: 	3.8.16
# torch version:  	2.0.1+cu117
# 2023-07-11 14:23:16,201 [INFO] ** TORCH CUDA version installed and working. **
# 2023-07-11 14:23:16,201 [INFO] >>>> using GPU
# 2023-07-11 14:23:16,461 [INFO] 255 / 255 images in /home/cyril/Desktop/cellpose/somatomotor_stacks folder have labels
# 2023-07-11 14:23:16,545 [INFO] 65 / 65 images in /home/cyril/Desktop/cellpose/visual_stacks folder have labels
# 2023-07-11 14:23:16,545 [INFO] >>>> during training rescaling images to fixed diameter of 3.3 pixels
# 2023-07-11 14:23:17,023 [INFO] flows precomputed
# 2023-07-11 14:23:17,040 [INFO] flows precomputed
# 2023-07-11 14:23:17,052 [WARNING] 19 train images with number of masks less than min_train_masks (5), removing from train set
# 2023-07-11 14:23:17,124 [INFO] >>>> median diameter set to = 3
# ...

# %%
# !python -m cellpose --train --pretrained_model CP --train_size --dir {str(train_path)} --test_dir {str(val_path)} --diam_mean=4 --verbose --use_gpu
# Out:
# 2023-06-02 14:21:49,158 [INFO] WRITING LOG OUTPUT TO /home/cyril/.cellpose/run.log
# 2023-06-02 14:21:49,158 [INFO]
# cellpose version: 	2.2.2
# platform:       	linux
# python version: 	3.8.16
# torch version:  	2.0.1+cu117
# 2023-06-02 14:21:50,067 [INFO] ** TORCH CUDA version installed and working. **
# 2023-06-02 14:21:50,067 [INFO] >>>> using GPU
# 2023-06-02 14:21:50,341 [INFO] 255 / 255 images in /home/cyril/Desktop/cellpose/somatomotor_stacks folder have labels
# 2023-06-02 14:21:50,419 [INFO] 65 / 65 images in /home/cyril/Desktop/cellpose/visual_stacks folder have labels
# 2023-06-02 14:21:50,419 [INFO] >>>> during training rescaling images to fixed diameter of 4.0 pixels
# 2023-06-02 14:21:50,419 [INFO] >> CP << model set to be used
# 2023-06-02 14:21:50,576 [INFO] >>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)
# 2023-06-02 14:21:51,007 [INFO] flows precomputed
# 2023-06-02 14:21:51,022 [INFO] flows precomputed
# ...
